# %% [markdown]
# <a href="https://colab.research.google.com/github/Dhamia96/-Crowdfunding_Data_with_Pandas/blob/main/test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df= pd.read_csv("kickstarter_sample.csv")
assert len(df)>0

# %%
df.head()
# Out:
#             created_at  backers_count  ... usd_pledged       usd_type
# 0  2009-04-25 05:37:50             25  ...       145.0  international
# 1  2009-08-25 18:21:02             36  ...      2562.0  international
# 2  2009-08-30 16:57:43             82  ...      3800.0  international
# 3  2009-09-14 23:58:49             10  ...       830.0  international
# 4  2009-10-11 20:28:44            156  ...     10021.0  international
#
# [5 rows x 39 columns]
